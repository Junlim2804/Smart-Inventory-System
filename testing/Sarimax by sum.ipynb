# %%
import pandas as pd 
import matplotlib

# %matplotlib inline

# %%
def parser(x):
    return pd.datetime.strptime(x,'%Y-%m-%d')
 
train_df = pd.read_csv('train.csv', header=0,usecols=['date','store','item','sales'])
train_df = train_df[train_df['store']==1]
train_df = train_df[train_df['item']==1]


train_df.head()

df=train_df.copy()

# %%
df.head()
# Out:
#          date  store  item  sales
# 0  2013-01-01      1     1     13
# 1  2013-01-02      1     1     11
# 2  2013-01-03      1     1     14
# 3  2013-01-04      1     1     13
# 4  2013-01-05      1     1     10

# %%
df['date'].min(), df['date'].max()
df['date'] = pd.to_datetime(df['date'])

# %%
df.isnull().sum()
# Out:
# date     0
# store    0
# item     0
# sales    0
# dtype: int64

# %%
df = df.groupby('date')['sales'].sum().reset_index()
df.head()
# Out:
#         date  sales
# 0 2013-01-01     13
# 1 2013-01-02     11
# 2 2013-01-03     14
# 3 2013-01-04     13
# 4 2013-01-05     10

# %%
df=df.set_index('date')
y=df

# %%
y = df['sales'].resample('MS').sum()

# %%
y['2013':].head()
# Out:
# date
# 2013-01-01    328
# 2013-02-01    322
# 2013-03-01    477
# 2013-04-01    522
# 2013-05-01    531
# Freq: MS, Name: sales, dtype: int64

# %%
y.plot(figsize=(15, 6))

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y, model='additive')
fig = decomposition.plot()

# %%
import itertools
import warnings
warnings.filterwarnings("ignore")
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 365) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 365)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 365)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 365)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 365)

# %%
min=10000000.00
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(y,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_stationarity=False,
                                            enforce_invertibility=False)
            results=mod.fit()
            if(results.aic<min):
                min=results.aic
                min_param=param
                min_param_seasonal=param_seasonal
            print('ARIMA{}x{}365 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# ARIMA(0, 0, 0)x(0, 0, 0, 365)365 - AIC:16307.7681346496
# ARIMA(0, 0, 0)x(0, 0, 1, 365)365 - AIC:12163.049209073004
# ARIMA(0, 0, 1)x(0, 0, 0, 365)365 - AIC:14727.239774771746
# ARIMA(0, 0, 1)x(0, 0, 1, 365)365 - AIC:11419.606446148324

# %%
print('ARIMA{}x{}12 - AIC:{}'.format(min_param, min_param_seasonal, min))

# %%
from pylab import rcParams
import statsmodels.api as sm
mod = sm.tsa.statespace.SARIMAX(y,order=(7,1,7),seasonal_order=(1,0,5,12),
                                       enforce_stationarity=False, enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-e72d5296a9b1> in <module>
#       3 mod = sm.tsa.statespace.SARIMAX(y,order=(7,1,7),seasonal_order=(1,0,5,12),
#       4                                        enforce_stationarity=False, enforce_invertibility=False)
# ----> 5 results = mod.fit()
#       6 print(results.summary().tables[1])
#
# ~\Anaconda3\envs\test\lib\site-packages\statsmodels\tsa\statespace\mlemodel.py in fit(self, start_params, transformed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, **kwargs)
#     443         """
#     444         if start_params is None:
# --> 445             start_params = self.start_params
#     446             transformed = True
#     447
#
# ~\Anaconda3\envs\test\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in start_params(self)
#     967             self._conditional_sum_squares(
#     968                 endog, self.k_seasonal_ar, self.polynomial_seasonal_ar,
# --> 969                 self.k_seasonal_ma, self.polynomial_seasonal_ma
#     970             )
#     971         )
#
# ~\Anaconda3\envs\test\lib\site-packages\statsmodels\tsa\statespace\sarimax.py in _conditional_sum_squares(endog, k_ar, polynomial_ar, k_ma, polynomial_ma, k_trend, trend_data)
#     843             if k_ma > 0:
#     844                 Y = endog[k:]
# --> 845                 X = lagmat(endog, k, trim='both')
#     846                 params_ar = np.linalg.pinv(X).dot(Y)
#     847                 residuals = Y - np.dot(X, params_ar)
#
# ~\Anaconda3\envs\test\lib\site-packages\statsmodels\tsa\tsatools.py in lagmat(x, maxlag, trim, original, use_pandas)
#     406         dropidx = nvar
#     407     if maxlag >= nobs:
# --> 408         raise ValueError("maxlag should be < nobs")
#     409     lm = np.zeros((nobs + maxlag, nvar * (maxlag + 1)))
#     410     for k in range(0, int(maxlag + 1)):
#
# ValueError: maxlag should be < nobs

# %%
results.plot_diagnostics(figsize=(16, 8))

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('date')
ax.set_ylabel('Sales')
# Out:
# Text(0, 0.5, 'Sales')

# %%
from sklearn.metrics import mean_absolute_error
from math import sqrt
from sklearn.metrics import mean_squared_error
expected =  y['2017-01-01':]
predictions = pred.predicted_mean

mae = mean_absolute_error(expected, predictions)
print('MAE: %f' % mae)
mse = mean_squared_error(expected, predictions)
print('MSE: %f' % mse)
rmse = sqrt(mse)
print('RMSE: %f' % rmse)
# Out:
# MAE: 24.177608
# MSE: 930.704542
# RMSE: 30.507451

# %%
pred_uc = results.get_forecast(steps=30)
pred_ci = pred_uc.conf_int()

pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
#ax.fill_between(pred_ci.index,
#                pred_ci.iloc[:, 0],
#                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Sales')

# %%
pred_uc.predicted
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-4548d6b11c01> in <module>
# ----> 1 pred_uc.predicted
#
# ~\Anaconda3\envs\pmdarima\lib\site-packages\statsmodels\base\wrapper.py in __getattribute__(self, attr)
#      33             pass
#      34
# ---> 35         obj = getattr(results, attr)
#      36         data = results.model.data
#      37         how = self._wrap_attrs.get(attr)
#
# AttributeError: 'PredictionResults' object has no attribute 'predicted'

# %%
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()
